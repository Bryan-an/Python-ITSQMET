# %%
from io import open

archivo_texto = open('diego.txt', 'w', encoding='utf-8')
frase = 'Esta es una recapitulación del tema archivos en Python'
archivo_texto.write(frase)
archivo_texto.close()

# %%
from io import open

arch = open('diego.txt', 'r', encoding='utf-8')
for linea in arch:
    print(linea)
    
arch.close()
# Out:
# Esta es una recapitulación del tema archivos en Python
#
# Esta es una segunda linea de texto
#
# Esta es una tercera linea de texto
#
#
#
# Uga la tortuga - Cuento infantil sobre la perseverancia
#
#
#
# - ¡Caramba, todo me sale mal!, se lamenta constantemente Uga, la tortuga.
#
#
#
# Y es que no es para menos: siempre llega tarde, es la última en acabar sus tareas, casi nunca consigue premios a la rapidez y, para colmo es una dormilona.
#
#
#
# - ¡Esto tiene que cambiar!,- se propuso un buen día, harta de que sus compañeros del bosque le recriminaran por su poco esfuerzo al realizar sus tareas.
#
#
#
# Y es que había optado por no intentar siquiera realizar actividades tan sencillas como amontonar hojitas secas caídas de los árboles en otoño, o quitar piedrecitas de camino hacia la charca donde chapoteaban los calurosos días de verano.
#
#
#
# - ¿Para qué preocuparme en hacer un trabajo que luego acaban haciendo mis compañeros? Mejor es dedicarme a jugar y a descansar.
#
#
#
# ...

# %%
from io import open

archivo_texto = open('diego.txt', 'r', encoding='utf-8')
lineas_texto = archivo_texto.readlines()
archivo_texto.close()
print(lineas_texto[0])
# Out:
# Esta es una recapitulación del tema archivos en Python

# %%
from io import open

archivo_texto = open('diego.txt', 'a', encoding='utf-8')
archivo_texto.write('\nEsta es una segunda linea de texto')
archivo_texto.write('\nEsta es una tercera linea de texto')
archivo_texto.close()

# %%
from io import open

arch = open('diego.txt', 'rt', encoding='utf-8')
datos = arch.read()
palabras = datos.split()
print('El número de palabras en el archivo de texto es:', len(palabras))
arch.close()
# Out:
# El número de palabras en el archivo de texto es: 489

# %%
# Frecuencia de palabras en el archivo de texto
import re
import string

frequency={}
document_text=open('diego.txt','r')
text_string=document_text.read().lower()
match_pattern=re.findall(r'\b[a-z]{3,15}\b',text_string)

for word in match_pattern:
    count=frequency.get(word,0)
    frequency[word]=count +1
    
frequency_list=frequency.keys()

for word in frequency_list:
    print(word,frequency[word])
# Out:
# esta 4
# una 6
# del 5
# tema 1
# archivos 1
# python 1
# segunda 1
# linea 2
# texto 2
# tercera 1
# uga 7
# tortuga 5
# cuento 4
# infantil 1
# sobre 2
# perseverancia 2
# caramba 2
# todo 3
# sale 1
# mal 1
# lamenta 1
# constantemente 1
# que 23
# para 6
# menos 1
# siempre 3
# llega 1
# tarde 1
# acabar 2
# sus 4
# tareas 4
# casi 1
# nunca 2
# consigue 1
# premios 1
# rapidez 1
# colmo 1
# dormilona 1
# esto 2
# tiene 1
# cambiar 2
# propuso 1
# buen 1
# harta 1
# eros 3
# bosque 2
# recriminaran 1
# por 6
# poco 1
# esfuerzo 3
# realizar 2
# optado 1
# intentar 1
# siquiera 1
# actividades 1
# tan 1
# sencillas 1
# como 1
# amontonar 1
# hojitas 1
# secas 1
# das 1
# los 4
# rboles 1
# quitar 1
# piedrecitas 1
# camino 1
# hacia 1
# charca 1
# donde 1
# chapoteaban 1
# calurosos 1
# verano 1
# preocuparme 1
# hacer 3
# trabajo 2
# luego 1
# acaban 1
# haciendo 1
# mis 1
# mejor 3
# dedicarme 1
# jugar 1
# descansar 1
# gran 1
# idea 1
# dijo 2
# hormiguita 3
# ...
